# %% [markdown]
# # Checkerboard demonstration
#
# This notebook runs all eight reverse-OU methods with identical inputs on the eight occupied cells of a 4-by-4 checkerboard. The default execution uses 300 training samples, 10,000 reference samples, 2,000 generated particles, and 300 reverse steps. Results are qualitative and are not a superiority claim.

# %% [markdown]
# ## Methods
#
# The columns show plain score matching, Stein-informed score matching, scalar Stein transport, and vectorized Stein transport. The rows distinguish deterministic probability-flow and stochastic reverse-SDE sampling.

# %%
import json
import os

import torch
from IPython.display import Image, Markdown, display

from stein_generative_modeling.checkerboard import (
    CheckerboardConfig,
    run_experiment,
    smoke_config,
)

# %%
mode = os.environ.get("STEIN_NOTEBOOK_MODE", "full").lower()
if mode not in {"full", "smoke"}:
    raise ValueError("STEIN_NOTEBOOK_MODE must be 'full' or 'smoke'")
config = smoke_config() if mode == "smoke" else CheckerboardConfig()
display(Markdown(f"**Execution mode:** `{mode}`"))
config
# Out:
# **Execution mode:** `full`
# CheckerboardConfig(dimension=2, cells_per_axis=4, lower_bound=-4.0, upper_bound=4.0, training_size=300, reference_size=10000, generated_size=2000, horizon=3.0, reverse_steps=300, regularization=0.001, scaling_factor=1.0, device='cpu', dtype='float64', seeds={'training': 4025, 'reference': 4026, 'initial_particles': 4027, 'forward_noise': 4028, 'reverse_brownian': 4029})

# %%
run_dir = run_experiment(config, progress=False)
print(f"Completed run: {run_dir.name}")
# Out:
# Completed run: seed4025_20260923T210418.627672Z

# %%
resolved = json.loads((run_dir / "config.json").read_text())
metadata = json.loads((run_dir / "run_metadata.json").read_text())
outputs = torch.load(run_dir / "samples.pt", map_location="cpu", weights_only=False)
status = {name: item["status"] for name, item in outputs.items()}
display(
    {
        "configuration": resolved,
        "method_status": status,
        "failures": metadata["failures"],
    }
)
# Out:
# {'configuration': {'cells_per_axis': 4,
#   'device': 'cpu',
#   'dimension': 2,
#   'dtype': 'float64',
#   'generated_size': 2000,
#   'horizon': 3.0,
#   'lower_bound': -4.0,
#   'method_labels': {'sm_plain_det': '$\\mathrm{SM}_{\\mathrm{plain}}^{\\mathrm{det}}$',
#    'sm_plain_sto': '$\\mathrm{SM}_{\\mathrm{plain}}^{\\mathrm{sto}}$',
#    'sm_stein_det': '$\\mathrm{SM}_{\\mathrm{stein}}^{\\mathrm{det}}$',
#    'sm_stein_sto': '$\\mathrm{SM}_{\\mathrm{stein}}^{\\mathrm{sto}}$',
#    'st_det': '$\\mathrm{ST}^{\\mathrm{det}}$',
#    'st_sto': '$\\mathrm{ST}^{\\mathrm{sto}}$',
#    'st_vec_det': '$\\mathrm{ST}_{\\mathrm{vec}}^{\\mathrm{det}}$',
#    'st_vec_sto': '$\\mathrm{ST}_{\\mathrm{vec}}^{\\mathrm{sto}}$'},
#   'methods': ['sm_plain_det',
#    'sm_stein_det',
#    'st_det',
#    'st_vec_det',
#    'sm_plain_sto',
#    'sm_stein_sto',
#    'st_sto',
#    'st_vec_sto'],
#   'occupied_cells': 8,
#   'plot_limits': {'x1': [-4.5, 4.5], 'x2': [-4.5, 4.5]},
#   'reference_size': 10000,
#   'regularization': 0.001,
#   'reverse_steps': 300,
#   'scaling_factor': 1.0,
#   'seeds': {'forward_noise': 4028,
#    'initial_particles': 4027,
#    'reference': 4026,
#    'reverse_brownian': 4029,
#    'training': 4025},
#   'step_size': 0.01,
#   'training_size': 300,
#   'upper_bound': 4.0},
#  'method_status': {'sm_plain_det': 'success',
#   'sm_stein_det': 'success',
#   'st_det': 'success',
#   'st_vec_det': 'success',
#   'sm_plain_sto': 'success',
#   'sm_stein_sto': 'success',
#   'st_sto': 'success',
#   'st_vec_sto': 'success'},
#  'failures': {}}

# %%
display(Markdown("## Target reference"))
display(Image(filename=str(run_dir / "reference.png")))
display(Markdown("## Eight-method comparison"))
display(Image(filename=str(run_dir / "comparison.png")))
# Out:
# ## Target reference
# ## Eight-method comparison
